# %%
import numpy as np
import astropy.io.fits as pyfits
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from scipy.stats import binned_statistic
import os

# %%
def sort_nums(filename):
    return int(filename.split('_')[-1].split('.')[0])

# %%
# directory_path = os.path.join(os.path.expanduser("~"), '/Volumes/Simulations/emissivity_ellipse_1_200')
# unsorted_files = [os.path.join(directory_path, name) for name in os.listdir(directory_path)]
# filtered_files = [file for file in unsorted_files if not os.path.basename(file).startswith("._")]
# organized_files = sorted(filtered_files, key=sort_nums)
file_name = 'emissivity.dat'

# %%
data = np.loadtxt(file_name)
radius = data[:, 0]
flux = data[:, 3]
emissivity = data[:, 4]

# radius_list = []
# emissivity_list = []
# for i in range(3): 
#     data = np.loadtxt(organized_files[i])
#     radius = data[:, 0]
#     emissivity = data[:, 4]
#     radius_list.append(radius)
#     emissivity_list.append(emissivity)

# %%
plt.figure(figsize=(8, 6))
plt.plot(radius, emissivity)
plt.plot(radius, emissivity1, 'r-')
# plt.plot(radius_list[0], emissivity_list[0], 'b-')
# plt.plot(radius_list[1], emissivity_list[1], 'g-')
# plt.plot(radius_list[2], emissivity_list[2], 'r-')

plt.xlabel('Radius')
plt.ylabel('Flux')
plt.title('Emissivity vs. Radius')
plt.xscale('log')
plt.yscale('log')
#plt.ylim(1e-3, 1e6)
#plt.legend()

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(radius, emissivity, 'r-')
# plt.plot(radius_list[0], emissivity_list[0], 'b-')
# plt.plot(radius_list[1], emissivity_list[1], 'g-')
# plt.plot(radius_list[2], emissivity_list[2], 'r-')

plt.xlabel('Radius')
plt.ylabel('Emissivity')
plt.title('Emissivity vs. Radius')
plt.xscale('log')
plt.yscale('log')
#plt.ylim(1e-3, 1e6)
#plt.legend()

plt.grid(True)

plt.show()
